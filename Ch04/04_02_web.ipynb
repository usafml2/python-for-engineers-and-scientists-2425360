# %% [markdown]
# # 04_02_web.ipynb - Web resources with requests and JSON

# %%
import json
import os

import requests

# %%
r = requests.get('https://www.gw-openscience.org/eventapi/json/GWTC-1-confident/GW150914/v3')

# %%
r
# Out:
# <Response [200]>

# %%
# if requests.get fails for network problems
# you can use the cached version in the exercise files:
# import pickle
# r = pickle.load(open('cache/GW150914-v3.pickle', 'rb'))

# %%
r.ok
# Out:
# True

# %%
r.content
# Out:
# b'{\n  "events": {\n    "GW150914-v3": {\n      "commonName": "GW150914",\n      "version": 3,\n      "catalog.shortName": "GWTC-1-confident",\n      "GPS": 1126259462.4,\n      "gracedb_id": "G184098",\n      "reference": "https://doi.org/10.7935/82H3-HH23",\n      "jsonurl": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3",\n      "mass_1_source": 35.6,\n      "mass_1_source_lower": -3.1,\n      "mass_1_source_upper": 4.7,\n      "mass_1_source_unit": "M_sun",\n      "mass_2_source": 30.6,\n      "mass_2_source_lower": -4.4,\n      "mass_2_source_upper": 3.0,\n      "mass_2_source_unit": "M_sun",\n      "network_matched_filter_snr": 26.0,\n      "network_matched_filter_snr_lower": -0.2,\n      "network_matched_filter_snr_upper": 0.1,\n      "network_matched_filter_snr_unit": "",\n      "luminosity_distance": 440.0,\n      "luminosity_distance_lower": -170.0,\n      "luminosity_distance_upper": 150.0,\n      "luminosity_distance_unit": "Mpc",\n      "chi_eff": -0.01,\n      "chi_eff_lower": -0.13,\n      "chi_eff_upper": 0.12,\n      "chi_eff_unit": "",\n      "total_mass_source": null,\n      "total_mass_source_lower": null,\n      "total_mass_source_upper": null,\n      "total_mass_source_unit": null,\n      "chirp_mass_source": 28.6,\n      "chirp_mass_source_lower": -1.5,\n      "chirp_mass_source_upper": 1.7,\n      "chirp_mass_source_unit": "M_sun",\n      "chirp_mass": null,\n      "chirp_mass_lower": null,\n      "chirp_mass_upper": null,\n      "chirp_mass_unit": null,\n      "redshift": 0.09,\n      "redshift_lower": -0.03,\n      "redshift_upper": 0.03,\n      "redshift_unit": "",\n      "far": 1e-07,\n      "far_lower": null,\n      "far_upper": null,\n      "far_unit": "yr^-1",\n      "p_astro": 1.0,\n      "p_astro_lower": null,\n      "p_astro_upper": null,\n      "p_astro_unit": "",\n      "final_mass_source": 63.1,\n      "final_mass_source_lower": -3.0,\n      "final_mass_source_upper": 3.4,\n      "final_mass_source_unit": "M_sun",\n      "strain": [\n        {\n          "GPSstart": 1126259447,\n          "detector": "H1",\n          "sampling_rate": 16384,\n          "duration": 32,\n          "format": "gwf",\n          "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.gwf"\n        },\n        {\n          "GPSstart": 1126259447,\n          "detector": "H1",\n          "sampling_rate": 16384,\n          "duration": 32,\n          "format": "hdf5",\n          "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.hdf5"\n        },\n        {\n          "GPSstart": 1126259447,\n          "detector": "H1",\n          "sampling_rate": 16384,\n          "duration": 32,\n          "format": "txt",\n          "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.txt.gz"\n        },\n        {\n          "GPSstart": 1126259447,\n          "detector": "H1",\n          "sampling_rate": 4096,\n          "duration": 32,\n          "format": "gwf",\n          "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.gwf"\n        },\n        {\n          "GPSstart": 1126259447,\n          "detector": "H1",\n          "sampling_rate": 4096,\n          "duration": 32,\n          "format": "hdf5",\n          "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.hdf5"\n        },\n        {\n          "GPSstart": 1126259447,\n          "detector": "H1",\n          "sampling_rate": 4096,\n          "duration": 32,\n          "format": "txt",\n          "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt.gz"\n        },\n        {\n          "GPSstart": 1126257415,\n          "detector": "H1",\n          "sampling_rate": 16384,\n          "duration": 4096,\n          "format": "gwf",\n          "url": "https://gwosc.o ...

# %%
print(r.text)
# Out:
# {
#   "events": {
#     "GW150914-v3": {
#       "commonName": "GW150914",
#       "version": 3,
#       "catalog.shortName": "GWTC-1-confident",
#       "GPS": 1126259462.4,
#       "gracedb_id": "G184098",
#       "reference": "https://doi.org/10.7935/82H3-HH23",
#       "jsonurl": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3",
#       "mass_1_source": 35.6,
#       "mass_1_source_lower": -3.1,
#       "mass_1_source_upper": 4.7,
#       "mass_1_source_unit": "M_sun",
#       "mass_2_source": 30.6,
#       "mass_2_source_lower": -4.4,
#       "mass_2_source_upper": 3.0,
#       "mass_2_source_unit": "M_sun",
#       "network_matched_filter_snr": 26.0,
#       "network_matched_filter_snr_lower": -0.2,
#       "network_matched_filter_snr_upper": 0.1,
#       "network_matched_filter_snr_unit": "",
#       "luminosity_distance": 440.0,
#       "luminosity_distance_lower": -170.0,
#       "luminosity_distance_upper": 150.0,
#       "luminosity_distance_unit": "Mpc",
#       "chi_eff": -0.01,
#       "chi_eff_lower": -0.13,
#       "chi_eff_upper": 0.12,
#       "chi_eff_unit": "",
#       "total_mass_source": null,
#       "total_mass_source_lower": null,
#       "total_mass_source_upper": null,
#       "total_mass_source_unit": null,
#       "chirp_mass_source": 28.6,
#       "chirp_mass_source_lower": -1.5,
#       "chirp_mass_source_upper": 1.7,
#       "chirp_mass_source_unit": "M_sun",
#       "chirp_mass": null,
#       "chirp_mass_lower": null,
#       "chirp_mass_upper": null,
#       "chirp_mass_unit": null,
#       "redshift": 0.09,
#       "redshift_lower": -0.03,
#       "redshift_upper": 0.03,
#       "redshift_unit": "",
#       "far": 1e-07,
#       "far_lower": null,
#       "far_upper": null,
#       "far_unit": "yr^-1",
#       "p_astro": 1.0,
#       "p_astro_lower": null,
#       "p_astro_upper": null,
#       "p_astro_unit": "",
#       "final_mass_source": 63.1,
#       "final_mass_source_lower": -3.0,
#       "final_mass_source_upper": 3.4,
#       "final_mass_source_unit": "M_sun",
#       "strain": [
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "sampling_rate": 16384,
#           "duration": 32,
#           "format": "gwf",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.gwf"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "sampling_rate": 16384,
#           "duration": 32,
#           "format": "hdf5",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.hdf5"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "sampling_rate": 16384,
#           "duration": 32,
#           "format": "txt",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.txt.gz"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "sampling_rate": 4096,
#           "duration": 32,
#           "format": "gwf",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.gwf"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "sampling_rate": 4096,
#           "duration": 32,
#           "format": "hdf5",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.hdf5"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "H1",
#           "sampling_rate": 4096,
#           "duration": 32,
#           "format": "txt",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt.gz"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "sampling_rate": 16384,
#           "duration": 4096,
#           "format": "gwf",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.gwf"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "sampling_rate": 16384,
#           "duration": 4096,
#           "format": "hdf5",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.hdf5"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "sampling_rate": 16384,
#           "duration": 4096,
#           "format": "txt",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "sampling_rate": 4096,
#           "duration": 4096,
#           "format": "gwf",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.gwf"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "sampling_rate": 4096,
#           "duration": 4096,
#           "format": "hdf5",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.hdf5"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "H1",
#           "sampling_rate": 4096,
#           "duration": 4096,
#           "format": "txt",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "sampling_rate": 16384,
#           "duration": 32,
#           "format": "gwf",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.gwf"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "sampling_rate": 16384,
#           "duration": 32,
#           "format": "hdf5",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.hdf5"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "sampling_rate": 16384,
#           "duration": 32,
#           "format": "txt",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.txt.gz"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "sampling_rate": 4096,
#           "duration": 32,
#           "format": "gwf",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.gwf"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "sampling_rate": 4096,
#           "duration": 32,
#           "format": "hdf5",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.hdf5"
#         },
#         {
#           "GPSstart": 1126259447,
#           "detector": "L1",
#           "sampling_rate": 4096,
#           "duration": 32,
#           "format": "txt",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.txt.gz"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "sampling_rate": 16384,
#           "duration": 4096,
#           "format": "gwf",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.gwf"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "sampling_rate": 16384,
#           "duration": 4096,
#           "format": "hdf5",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.hdf5"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "sampling_rate": 16384,
#           "duration": 4096,
#           "format": "txt",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "sampling_rate": 4096,
#           "duration": 4096,
#           "format": "gwf",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.gwf"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "sampling_rate": 4096,
#           "duration": 4096,
#           "format": "hdf5",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.hdf5"
#         },
#         {
#           "GPSstart": 1126257415,
#           "detector": "L1",
#           "sampling_rate": 4096,
#           "duration": 4096,
#           "format": "txt",
#           "url": "https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz"
#         }
#       ],
#       "parameters": {
#         "GWTC-1-confident_GW150914_R2_pe_combined": {
#           "waveform_family": "C01:Mixed",
#           "data_url": "https://zenodo.org/api/files/ecf41927-9275-47da-8b37-e299693fe5cb/IGWN-GWTC2p1-v2-GW150914_095045_PEDataRelease_mixed_cosmo.h5",
#           "date_added": "2022-05-13",
#           "is_preferred": false,
#           "pipeline_type": "pe",
#           "links": {
#             "posterior-samples": "https://doi.org/10.5281/zenodo.6513631",
#             "skymap": "https://zenodo.org/api/files/ecf41927-9275-47da-8b37-e299693fe5cb/IGWN-GWTC2p1-v2-PESkyMaps.tar.gz"
#           },
#           "chirp_mass_source": 27.9,
#           "chirp_mass_source_lower": -1.5,
#           "chirp_mass_source_upper": 1.7,
#           "chirp_mass_source_unit": "M_sun",
#           "chirp_mass_source_meta": "na",
#           "chi_eff": -0.04,
#           "chi_eff_lower": -0.14,
#           "chi_eff_upper": 0.12,
#           "chi_eff_unit": "",
#           "chi_eff_meta": "na",
#           "final_mass_source": 61.5,
#           "final_mass_source_lower": -2.9,
#           "final_mass_source_upper": 3.4,
#           "final_mass_source_unit": "M_sun",
#           "final_mass_source_meta": "na",
#           "final_spin": 0.68,
#           "final_spin_lower": -0.05,
#           "final_spin_upper": 0.05,
#           "final_spin_unit": "",
#           "final_spin_meta": "na",
#           "luminosity_distance": 470.0,
#           "luminosity_distance_lower": -160.0,
#           "luminosity_distance_upper": 140.0,
#           "luminosity_distance_unit": "Mpc",
#           "luminosity_distance_meta": "na",
#           "mass_1_source": 34.6,
#           "mass_1_source_lower": -2.6,
#           "mass_1_source_upper": 4.4,
#           "mass_1_source_unit": "M_sun",
#           "mass_1_source_meta": "na",
#           "mass_2_source": 30.0,
#           "mass_2_source_lower": -4.6,
#           "mass_2_source_upper": 2.9,
#           "mass_2_source_unit": "M_sun",
#           "mass_2_source_meta": "na",
#           "network_matched_filter_snr": 26.0,
#           "network_matched_filter_snr_lower": -0.2,
#           "network_matched_filter_snr_upper": 0.1,
#           "network_matched_filter_snr_unit": "",
#           "network_matched_filter_snr_meta": "na",
#           "redshift": 0.1,
#           "redshift_lower": -0.03,
#           "redshift_upper": 0.03,
#           "redshift_unit": "",
#           "redshift_meta": "na",
#           "sky_area": 250.0,
#           "sky_area_lower": null,
#           "sky_area_upper": null,
#           "sky_area_unit": "deg^2",
#           "sky_area_meta": "na",
#           "total_mass_source": 64.5,
#           "total_mass_source_lower": -3.2,
#           "total_mass_source_upper": 3.7,
#           "total_mass_source_unit": "M_sun",
#           "total_mass_source_meta": "na"
#         },
#         "gwtc1_cwb_GW150914": {
#           "waveform_family": "na",
#           "data_url": "",
#           "date_added": "2020-02-19",
#           "is_preferred": false,
#           "pipeline_type": "search",
#           "links": {},
#           "far": 0.000163,
#           "far_lower": null,
#           "far_upper": null,
#           "far_unit": "yr^-1",
#           "far_meta": "na",
#           "network_matched_filter_snr": 25.2,
#           "network_matched_filter_snr_lower": null,
#           "network_matched_filter_snr_upper": null,
#           "network_matched_filter_snr_unit": "",
#           "network_matched_filter_snr_meta": "na",
#           "p_astro": 1.0,
#           "p_astro_lower": null,
#           "p_astro_upper": null,
#           "p_astro_unit": "",
#           "p_astro_meta": "na"
#         },
#         "gwtc1_gstlal_GW150914": {
#           "waveform_family": "na",
#           "data_url": "",
#           "date_added": "2020-02-19",
#           "is_preferred": false,
#           "pipeline_type": "search",
#           "links": {},
#           "far": 1e-07,
#           "far_lower": null,
#           "far_upper": null,
#           "far_unit": "yr^-1",
#           "far_meta": "na",
#           "network_matched_filter_snr": 24.4,
#           "network_matched_filter_snr_lower": null,
#           "network_matched_filter_snr_upper": null,
#           "network_matched_filter_snr_unit": "",
#           "network_matched_filter_snr_meta": "na",
#           "p_astro": 1.0,
#           "p_astro_lower": null,
#           "p_astro_upper": null,
#           "p_astro_unit": "",
#           "p_astro_meta": "na"
#         },
#         "gwtc1_pe_GW150914": {
#           "waveform_family": "Overall_posterior",
#           "data_url": "https://dcc.ligo.org/public/0157/P1800370/005/GW150914_GWTC-1.hdf5",
#           "date_added": "2020-02-19",
#           "is_preferred": true,
#           "pipeline_type": "pe",
#           "links": {
#             "posterior-samples": "https://dcc.ligo.org/LIGO-P1800370/public"
#           },
#           "a_final": 0.69,
#           "a_final_lower": -0.04,
#           "a_final_upper": 0.05,
#           "a_final_unit": "",
#           "a_final_meta": "na",
#           "chirp_mass_source": 28.6,
#           "chirp_mass_source_lower": -1.5,
#           "chirp_mass_source_upper": 1.7,
#           "chirp_mass_source_unit": "M_sun",
#           "chirp_mass_source_meta": "na",
#           "chi_eff": -0.01,
#           "chi_eff_lower": -0.13,
#           "chi_eff_upper": 0.12,
#           "chi_eff_unit": "",
#           "chi_eff_meta": "na",
#           "E_rad": 3.1,
#           "E_rad_lower": -0.4,
#           "E_rad_upper": 0.4,
#           "E_rad_unit": "M_sun c^2",
#           "E_rad_meta": "na",
#           "final_mass_source": 63.1,
#           "final_mass_source_lower": -3.0,
#           "final_mass_source_upper": 3.4,
#           "final_mass_source_unit": "M_sun",
#           "final_mass_source_meta": "na",
#           "geocent_time": 1126259462.4,
#           "geocent_time_lower": null,
#           "geocent_time_upper": null,
#           "geocent_time_unit": "",
#           "geocent_time_meta": "na",
#           "luminosity_distance": 440.0,
#           "luminosity_distance_lower": -170.0,
#           "luminosity_distance_upper": 150.0,
#           "luminosity_distance_unit": "Mpc",
#           "luminosity_distance_meta": "na",
#           "L_peak": 3.6,
#           "L_peak_lower": -0.4,
#           "L_peak_upper": 0.4,
#           "L_peak_unit": "10^56 erg s^-1",
#           "L_peak_meta": "na",
#           "mass_1_source": 35.6,
#           "mass_1_source_lower": -3.1,
#           "mass_1_source_upper": 4.7,
#           "mass_1_source_unit": "M_sun",
#           "mass_1_source_meta": "na",
#           "mass_2_source": 30.6,
#           "mass_2_source_lower": -4.4,
#           "mass_2_source_upper": 3.0,
#           "mass_2_source_unit": "M_sun",
#           "mass_2_source_meta": "na",
#           "redshift": 0.09,
#           "redshift_lower": -0.03,
#           "redshift_upper": 0.03,
#           "redshift_unit": "",
#           "redshift_meta": "na",
#           "sky_area": 182.0,
#           "sky_area_lower": null,
#           "sky_area_upper": null,
#           "sky_area_unit": "deg^2",
#           "sky_area_meta": "na"
#         },
#         "gwtc1_pycbc_GW150914": {
#           "waveform_family": "na",
#           "data_url": "",
#           "date_added": "2020-02-19",
#           "is_preferred": false,
#           "pipeline_type": "search",
#           "links": {},
#           "far": 1.5300000000000003e-05,
#           "far_lower": null,
#           "far_upper": null,
#           "far_unit": "yr^-1",
#           "far_meta": "na",
#           "network_matched_filter_snr": 23.6,
#           "network_matched_filter_snr_lower": null,
#           "network_matched_filter_snr_upper": null,
#           "network_matched_filter_snr_unit": "",
#           "network_matched_filter_snr_meta": "na",
#           "p_astro": 1.0,
#           "p_astro_lower": null,
#           "p_astro_upper": null,
#           "p_astro_unit": "",
#           "p_astro_meta": "na"
#         }
#       }
#     }
#   }
# }

# %%
jsondict = json.loads(r.text)

# %%
jsondict['events']['GW150914-v3']
# Out:
# {'commonName': 'GW150914',
#  'version': 3,
#  'catalog.shortName': 'GWTC-1-confident',
#  'GPS': 1126259462.4,
#  'gracedb_id': 'G184098',
#  'reference': 'https://doi.org/10.7935/82H3-HH23',
#  'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3',
#  'mass_1_source': 35.6,
#  'mass_1_source_lower': -3.1,
#  'mass_1_source_upper': 4.7,
#  'mass_1_source_unit': 'M_sun',
#  'mass_2_source': 30.6,
#  'mass_2_source_lower': -4.4,
#  'mass_2_source_upper': 3.0,
#  'mass_2_source_unit': 'M_sun',
#  'network_matched_filter_snr': 26.0,
#  'network_matched_filter_snr_lower': -0.2,
#  'network_matched_filter_snr_upper': 0.1,
#  'network_matched_filter_snr_unit': '',
#  'luminosity_distance': 440.0,
#  'luminosity_distance_lower': -170.0,
#  'luminosity_distance_upper': 150.0,
#  'luminosity_distance_unit': 'Mpc',
#  'chi_eff': -0.01,
#  'chi_eff_lower': -0.13,
#  'chi_eff_upper': 0.12,
#  'chi_eff_unit': '',
#  'total_mass_source': None,
#  'total_mass_source_lower': None,
#  'total_mass_source_upper': None,
#  'total_mass_source_unit': None,
#  'chirp_mass_source': 28.6,
#  'chirp_mass_source_lower': -1.5,
#  'chirp_mass_source_upper': 1.7,
#  'chirp_mass_source_unit': 'M_sun',
#  'chirp_mass': None,
#  'chirp_mass_lower': None,
#  'chirp_mass_upper': None,
#  'chirp_mass_unit': None,
#  'redshift': 0.09,
#  'redshift_lower': -0.03,
#  'redshift_upper': 0.03,
#  'redshift_unit': '',
#  'far': 1e-07,
#  'far_lower': None,
#  'far_upper': None,
#  'far_unit': 'yr^-1',
#  'p_astro': 1.0,
#  'p_astro_lower': None,
#  'p_astro_upper': None,
#  'p_astro_unit': '',
#  'final_mass_source': 63.1,
#  'final_mass_source_lower': -3.0,
#  'final_mass_source_upper': 3.4,
#  'final_mass_source_unit': 'M_sun',
#  'strain': [{'GPSstart': 1126259447,
#    'detector': 'H1',
#    'sampling_rate': 16384,
#    'duration': 32,
#    'format': 'gwf',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.gwf'},
#   {'GPSstart': 1126259447,
#    'detector': 'H1',
#    'sampling_rate': 16384,
#    'duration': 32,
#    'format': 'hdf5',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.hdf5'},
#   {'GPSstart': 1126259447,
#    'detector': 'H1',
#    'sampling_rate': 16384,
#    'duration': 32,
#    'format': 'txt',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.txt.gz'},
#   {'GPSstart': 1126259447,
#    'detector': 'H1',
#    'sampling_rate': 4096,
#    'duration': 32,
#    'format': 'gwf',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.gwf'},
#   {'GPSstart': 1126259447,
#    'detector': 'H1',
#    'sampling_rate': 4096,
#    'duration': 32,
#    'format': 'hdf5',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.hdf5'},
#   {'GPSstart': 1126259447,
#    'detector': 'H1',
#    'sampling_rate': 4096,
#    'duration': 32,
#    'format': 'txt',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt.gz'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'sampling_rate': 16384,
#    'duration': 4096,
#    'format': 'gwf',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.gwf'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'sampling_rate': 16384,
#    'duration': 4096,
#    'format': 'hdf5',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.hdf5'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'sampling_rate': 16384,
#    'duration': 4096,
#    'format': 'txt',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'sampling_rate': 4096,
#    'duration': 4096,
#    'format': 'gwf',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.gwf'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'sampling_rate': 4096,
#    'duration': 4096,
#    'format': 'hdf5',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.hdf5'},
#   {'GPSstart': 1126257415,
#    'detector': 'H1',
#    'sampling_rate': 4096,
#    'duration': 4096,
#    'format': 'txt',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'sampling_rate': 16384,
#    'duration': 32,
#    'format': 'gwf',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.gwf'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'sampling_rate': 16384,
#    'duration': 32,
#    'format': 'hdf5',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.hdf5'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'sampling_rate': 16384,
#    'duration': 32,
#    'format': 'txt',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.txt.gz'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'sampling_rate': 4096,
#    'duration': 32,
#    'format': 'gwf',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.gwf'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'sampling_rate': 4096,
#    'duration': 32,
#    'format': 'hdf5',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.hdf5'},
#   {'GPSstart': 1126259447,
#    'detector': 'L1',
#    'sampling_rate': 4096,
#    'duration': 32,
#    'format': 'txt',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.txt.gz'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'sampling_rate': 16384,
#    'duration': 4096,
#    'format': 'gwf',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.gwf'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'sampling_rate': 16384,
#    'duration': 4096,
#    'format': 'hdf5',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.hdf5'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'sampling_rate': 16384,
#    'duration': 4096,
#    'format': 'txt',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'sampling_rate': 4096,
#    'duration': 4096,
#    'format': 'gwf',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.gwf'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'sampling_rate': 4096,
#    'duration': 4096,
#    'format': 'hdf5',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.hdf5'},
#   {'GPSstart': 1126257415,
#    'detector': 'L1',
#    'sampling_rate': 4096,
#    'duration': 4096,
#    'format': 'txt',
#    'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz'}],
#  'parameters': {'GWTC-1-confident_GW150914_R2_pe_combined': {'waveform_family': 'C01:Mixed',
#    'data_url': 'https://zenodo.org/api/files/ecf41927-9275-47da-8b37-e299693fe5cb/IGWN-GWTC2p1-v2-GW150914_095045_PEDataRelease_mixed_cosmo.h5',
#    'date_added': '2022-05-13',
#    'is_preferred': False,
#    'pipeline_type': 'pe',
#    'links': {'posterior-samples': 'https://doi.org/10.5281/zenodo.6513631',
#     'skymap': 'https://zenodo.org/api/files/ecf41927-9275-47da-8b37-e299693fe5cb/IGWN-GWTC2p1-v2-PESkyMaps.tar.gz'},
#    'chirp_mass_source': 27.9,
#    'chirp_mass_source_lower': -1.5,
#    'chirp_mass_source_upper': 1.7,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_meta': 'na',
#    'chi_eff': -0.04,
#    'chi_eff_lower': -0.14,
#    'chi_eff_upper': 0.12,
#    'chi_eff_unit': '',
#    'chi_eff_meta': 'na',
#    'final_mass_source': 61.5,
#    'final_mass_source_lower': -2.9,
#    'final_mass_source_upper': 3.4,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_meta': 'na',
#    'final_spin': 0.68,
#    'final_spin_lower': -0.05,
#    'final_spin_upper': 0.05,
#    'final_spin_unit': '',
#    'final_spin_meta': 'na',
#    'luminosity_distance': 470.0,
#    'luminosity_distance_lower': -160.0,
#    'luminosity_distance_upper': 140.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_meta': 'na',
#    'mass_1_source': 34.6,
#    'mass_1_source_lower': -2.6,
#    'mass_1_source_upper': 4.4,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_meta': 'na',
#    'mass_2_source': 30.0,
#    'mass_2_source_lower': -4.6,
#    'mass_2_source_upper': 2.9,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_meta': 'na',
#    'network_matched_filter_snr': 26.0,
#    'network_matched_filter_snr_lower': -0.2,
#    'network_matched_filter_snr_upper': 0.1,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_meta': 'na',
#    'redshift': 0.1,
#    'redshift_lower': -0.03,
#    'redshift_upper': 0.03,
#    'redshift_unit': '',
#    'redshift_meta': 'na',
#    'sky_area': 250.0,
#    'sky_area_lower': None,
#    'sky_area_upper': None,
#    'sky_area_unit': 'deg^2',
#    'sky_area_meta': 'na',
#    'total_mass_source': 64.5,
#    'total_mass_source_lower': -3.2,
#    'total_mass_source_upper': 3.7,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_meta': 'na'},
#   'gwtc1_cwb_GW150914': {'waveform_family': 'na',
#    'data_url': '',
#    'date_added': '2020-02-19',
#    'is_preferred': False,
#    'pipeline_type': 'search',
#    'links': {},
#    'far': 0.000163,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': 'yr^-1',
#    'far_meta': 'na',
#    'network_matched_filter_snr': 25.2,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_meta': 'na',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'p_astro_meta': 'na'},
#   'gwtc1_gstlal_GW150914': {'waveform_family': 'na',
#    'data_url': '',
#    'date_added': '2020-02-19',
#    'is_preferred': False,
#    'pipeline_type': 'search',
#    'links': {},
#    'far': 1e-07,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': 'yr^-1',
#    'far_meta': 'na',
#    'network_matched_filter_snr': 24.4,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_meta': 'na',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'p_astro_meta': 'na'},
#   'gwtc1_pe_GW150914': {'waveform_family': 'Overall_posterior',
#    'data_url': 'https://dcc.ligo.org/public/0157/P1800370/005/GW150914_GWTC-1.hdf5',
#    'date_added': '2020-02-19',
#    'is_preferred': True,
#    'pipeline_type': 'pe',
#    'links': {'posterior-samples': 'https://dcc.ligo.org/LIGO-P1800370/public'},
#    'a_final': 0.69,
#    'a_final_lower': -0.04,
#    'a_final_upper': 0.05,
#    'a_final_unit': '',
#    'a_final_meta': 'na',
#    'chirp_mass_source': 28.6,
#    'chirp_mass_source_lower': -1.5,
#    'chirp_mass_source_upper': 1.7,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_meta': 'na',
#    'chi_eff': -0.01,
#    'chi_eff_lower': -0.13,
#    'chi_eff_upper': 0.12,
#    'chi_eff_unit': '',
#    'chi_eff_meta': 'na',
#    'E_rad': 3.1,
#    'E_rad_lower': -0.4,
#    'E_rad_upper': 0.4,
#    'E_rad_unit': 'M_sun c^2',
#    'E_rad_meta': 'na',
#    'final_mass_source': 63.1,
#    'final_mass_source_lower': -3.0,
#    'final_mass_source_upper': 3.4,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_meta': 'na',
#    'geocent_time': 1126259462.4,
#    'geocent_time_lower': None,
#    'geocent_time_upper': None,
#    'geocent_time_unit': '',
#    'geocent_time_meta': 'na',
#    'luminosity_distance': 440.0,
#    'luminosity_distance_lower': -170.0,
#    'luminosity_distance_upper': 150.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_meta': 'na',
#    'L_peak': 3.6,
#    'L_peak_lower': -0.4,
#    'L_peak_upper': 0.4,
#    'L_peak_unit': '10^56 erg s^-1',
#    'L_peak_meta': 'na',
#    'mass_1_source': 35.6,
#    'mass_1_source_lower': -3.1,
#    'mass_1_source_upper': 4.7,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_meta': 'na',
#    'mass_2_source': 30.6,
#    'mass_2_source_lower': -4.4,
#    'mass_2_source_upper': 3.0,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_meta': 'na',
#    'redshift': 0.09,
#    'redshift_lower': -0.03,
#    'redshift_upper': 0.03,
#    'redshift_unit': '',
#    'redshift_meta': 'na',
#    'sky_area': 182.0,
#    'sky_area_lower': None,
#    'sky_area_upper': None,
#    'sky_area_unit': 'deg^2',
#    'sky_area_meta': 'na'},
#   'gwtc1_pycbc_GW150914': {'waveform_family': 'na',
#    'data_url': '',
#    'date_added': '2020-02-19',
#    'is_preferred': False,
#    'pipeline_type': 'search',
#    'links': {},
#    'far': 1.5300000000000003e-05,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': 'yr^-1',
#    'far_meta': 'na',
#    'network_matched_filter_snr': 23.6,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_meta': 'na',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'p_astro_meta': 'na'}}}

# %%
jsondict['events']['GW150914-v3']['mass_1_source'], jsondict['events']['GW150914-v3']['mass_2_source']
# Out:
# (35.6, 30.6)

# %%
jsondict['events']['GW150914-v3']['strain']
# Out:
# [{'GPSstart': 1126259447,
#   'detector': 'H1',
#   'sampling_rate': 16384,
#   'duration': 32,
#   'format': 'gwf',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.gwf'},
#  {'GPSstart': 1126259447,
#   'detector': 'H1',
#   'sampling_rate': 16384,
#   'duration': 32,
#   'format': 'hdf5',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.hdf5'},
#  {'GPSstart': 1126259447,
#   'detector': 'H1',
#   'sampling_rate': 16384,
#   'duration': 32,
#   'format': 'txt',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126259447-32.txt.gz'},
#  {'GPSstart': 1126259447,
#   'detector': 'H1',
#   'sampling_rate': 4096,
#   'duration': 32,
#   'format': 'gwf',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.gwf'},
#  {'GPSstart': 1126259447,
#   'detector': 'H1',
#   'sampling_rate': 4096,
#   'duration': 32,
#   'format': 'hdf5',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.hdf5'},
#  {'GPSstart': 1126259447,
#   'detector': 'H1',
#   'sampling_rate': 4096,
#   'duration': 32,
#   'format': 'txt',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt.gz'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'sampling_rate': 16384,
#   'duration': 4096,
#   'format': 'gwf',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.gwf'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'sampling_rate': 16384,
#   'duration': 4096,
#   'format': 'hdf5',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.hdf5'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'sampling_rate': 16384,
#   'duration': 4096,
#   'format': 'txt',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'sampling_rate': 4096,
#   'duration': 4096,
#   'format': 'gwf',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.gwf'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'sampling_rate': 4096,
#   'duration': 4096,
#   'format': 'hdf5',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.hdf5'},
#  {'GPSstart': 1126257415,
#   'detector': 'H1',
#   'sampling_rate': 4096,
#   'duration': 4096,
#   'format': 'txt',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'sampling_rate': 16384,
#   'duration': 32,
#   'format': 'gwf',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.gwf'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'sampling_rate': 16384,
#   'duration': 32,
#   'format': 'hdf5',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.hdf5'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'sampling_rate': 16384,
#   'duration': 32,
#   'format': 'txt',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126259447-32.txt.gz'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'sampling_rate': 4096,
#   'duration': 32,
#   'format': 'gwf',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.gwf'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'sampling_rate': 4096,
#   'duration': 32,
#   'format': 'hdf5',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.hdf5'},
#  {'GPSstart': 1126259447,
#   'detector': 'L1',
#   'sampling_rate': 4096,
#   'duration': 32,
#   'format': 'txt',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.txt.gz'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'sampling_rate': 16384,
#   'duration': 4096,
#   'format': 'gwf',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.gwf'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'sampling_rate': 16384,
#   'duration': 4096,
#   'format': 'hdf5',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.hdf5'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'sampling_rate': 16384,
#   'duration': 4096,
#   'format': 'txt',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_16KHZ_R1-1126257415-4096.txt.gz'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'sampling_rate': 4096,
#   'duration': 4096,
#   'format': 'gwf',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.gwf'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'sampling_rate': 4096,
#   'duration': 4096,
#   'format': 'hdf5',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.hdf5'},
#  {'GPSstart': 1126257415,
#   'detector': 'L1',
#   'sampling_rate': 4096,
#   'duration': 4096,
#   'format': 'txt',
#   'url': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126257415-4096.txt.gz'}]

# %%
hdffiles = [file['url'] for file in jsondict['events']['GW150914-v3']['strain']
                        if file['duration'] == 32 and file['sampling_rate'] == 4096
                                                  and file['format'] == 'hdf5']

# %%
hdffiles
# Out:
# ['https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/H-H1_GWOSC_4KHZ_R1-1126259447-32.hdf5',
#  'https://gwosc.org/eventapi/json/GWTC-1-confident/GW150914/v3/L-L1_GWOSC_4KHZ_R1-1126259447-32.hdf5']

# %%
def dump(url, filename):
    r = requests.get(url)
    
    with open(filename, 'wb') as outfile:
        outfile.write(r.content)

# %%
for hdffile in hdffiles:
    dump(hdffile, os.path.basename(hdffile))

# %%
# in case of network trouble, copies of these files can be found in the folder "cache"

# %%
r = requests.get('https://www.gw-openscience.org/eventapi/json/query/show',
                 params={'min-mass-1-source': 50, 'min-mass-2-source': 30})

# %%
json.loads(r.text)
# Out:
# {'events': {'GW200220_061928-v1': {'commonName': 'GW200220_061928',
#    'version': 1,
#    'catalog.shortName': 'GWTC-3-confident',
#    'GPS': 1266214786.7,
#    'reference': '/GWTC-3/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-3-confident/GW200220_061928/v1',
#    'mass_1_source': 87.0,
#    'mass_1_source_lower': -23.0,
#    'mass_1_source_upper': 40.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 61.0,
#    'mass_2_source_lower': -25.0,
#    'mass_2_source_upper': 26.0,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 7.2,
#    'network_matched_filter_snr_lower': -0.7,
#    'network_matched_filter_snr_upper': 0.4,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 6000.0,
#    'luminosity_distance_lower': -3100.0,
#    'luminosity_distance_upper': 4800.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.06,
#    'chi_eff_lower': -0.38,
#    'chi_eff_upper': 0.4,
#    'chi_eff_unit': '',
#    'total_mass_source': 148.0,
#    'total_mass_source_lower': -33.0,
#    'total_mass_source_upper': 55.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 62.0,
#    'chirp_mass_source_lower': -15.0,
#    'chirp_mass_source_upper': 23.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.9,
#    'redshift_lower': -0.4,
#    'redshift_upper': 0.55,
#    'redshift_unit': '',
#    'far': 6.8,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.62376,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 141.0,
#    'final_mass_source_lower': -31.0,
#    'final_mass_source_upper': 51.0,
#    'final_mass_source_unit': 'M_sun'},
#   'GW200216_220804-v1': {'commonName': 'GW200216_220804',
#    'version': 1,
#    'catalog.shortName': 'GWTC-3-confident',
#    'GPS': 1265926102.8,
#    'reference': '/GWTC-3/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-3-confident/GW200216_220804/v1',
#    'mass_1_source': 51.0,
#    'mass_1_source_lower': -13.0,
#    'mass_1_source_upper': 22.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 30.0,
#    'mass_2_source_lower': -16.0,
#    'mass_2_source_upper': 14.0,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 8.1,
#    'network_matched_filter_snr_lower': -0.5,
#    'network_matched_filter_snr_upper': 0.4,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 3800.0,
#    'luminosity_distance_lower': -2000.0,
#    'luminosity_distance_upper': 3000.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.1,
#    'chi_eff_lower': -0.36,
#    'chi_eff_upper': 0.34,
#    'chi_eff_unit': '',
#    'total_mass_source': 81.0,
#    'total_mass_source_lower': -14.0,
#    'total_mass_source_upper': 20.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 32.9,
#    'chirp_mass_source_lower': -8.5,
#    'chirp_mass_source_upper': 9.3,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.63,
#    'redshift_lower': -0.29,
#    'redshift_upper': 0.37,
#    'redshift_unit': '',
#    'far': 0.35,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.77277,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 78.0,
#    'final_mass_source_lower': -13.0,
#    'final_mass_source_upper': 19.0,
#    'final_mass_source_unit': 'M_sun'},
#   '200114_020818-v1': {'commonName': '200114_020818',
#    'version': 1,
#    'catalog.shortName': 'O3_IMBH_marginal',
#    'GPS': 1263002916.2,
#    'reference': '/O3_IMBH_marginal/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/O3_IMBH_marginal/200114_020818/v1',
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_upper': None,
#    'mass_1_source_unit': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_upper': None,
#    'mass_2_source_unit': None,
#    'network_matched_filter_snr': 14.5,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_upper': None,
#    'luminosity_distance_unit': None,
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_upper': None,
#    'chi_eff_unit': None,
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_upper': None,
#    'total_mass_source_unit': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_upper': None,
#    'redshift_unit': None,
#    'far': 0.058,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_upper': None,
#    'final_mass_source_unit': None},
#   'GW191109_010717-v1': {'commonName': 'GW191109_010717',
#    'version': 1,
#    'catalog.shortName': 'GWTC-3-confident',
#    'GPS': 1257296855.2,
#    'reference': '/GWTC-3/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-3-confident/GW191109_010717/v1',
#    'mass_1_source': 65.0,
#    'mass_1_source_lower': -11.0,
#    'mass_1_source_upper': 11.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 47.0,
#    'mass_2_source_lower': -13.0,
#    'mass_2_source_upper': 15.0,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 17.3,
#    'network_matched_filter_snr_lower': -0.5,
#    'network_matched_filter_snr_upper': 0.5,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 1290.0,
#    'luminosity_distance_lower': -650.0,
#    'luminosity_distance_upper': 1130.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': -0.29,
#    'chi_eff_lower': -0.31,
#    'chi_eff_upper': 0.42,
#    'chi_eff_unit': '',
#    'total_mass_source': 112.0,
#    'total_mass_source_lower': -16.0,
#    'total_mass_source_upper': 20.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 47.5,
#    'chirp_mass_source_lower': -7.5,
#    'chirp_mass_source_upper': 9.6,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.25,
#    'redshift_lower': -0.12,
#    'redshift_upper': 0.18,
#    'redshift_unit': '',
#    'far': 0.00018,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.99,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 107.0,
#    'final_mass_source_lower': -15.0,
#    'final_mass_source_upper': 18.0,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190818_232544-v1': {'commonName': 'GW190818_232544',
#    'version': 1,
#    'catalog.shortName': 'IAS-O3a',
#    'GPS': 1250205962.3,
#    'reference': '/IAS-O3a/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/IAS-O3a/GW190818_232544/v1',
#    'mass_1_source': 70.0,
#    'mass_1_source_lower': -20.0,
#    'mass_1_source_upper': 50.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 34.0,
#    'mass_2_source_lower': -19.0,
#    'mass_2_source_upper': 21.0,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 8.07,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 6000.0,
#    'luminosity_distance_lower': -3000.0,
#    'luminosity_distance_upper': 7000.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.7,
#    'chi_eff_lower': -1.2,
#    'chi_eff_upper': 0.2,
#    'chi_eff_unit': '',
#    'total_mass_source': 110.0,
#    'total_mass_source_lower': -30.0,
#    'total_mass_source_upper': 40.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 41.0,
#    'chirp_mass_source_lower': -13.0,
#    'chirp_mass_source_upper': 15.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 80.0,
#    'chirp_mass_lower': -30.0,
#    'chirp_mass_upper': 30.0,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.9,
#    'redshift_lower': -0.4,
#    'redshift_upper': 0.8,
#    'redshift_unit': '',
#    'far': 0.29,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.81,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_upper': None,
#    'final_mass_source_unit': None},
#   'GW190814_192009-v1': {'commonName': 'GW190814_192009',
#    'version': 1,
#    'catalog.shortName': 'IAS-O3a',
#    'GPS': 1249845627.6,
#    'reference': '/IAS-O3a/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/IAS-O3a/GW190814_192009/v1',
#    'mass_1_source': 80.0,
#    'mass_1_source_lower': -30.0,
#    'mass_1_source_upper': 110.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 50.0,
#    'mass_2_source_lower': -30.0,
#    'mass_2_source_upper': 30.0,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 7.96,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 9000.0,
#    'luminosity_distance_lower': -6000.0,
#    'luminosity_distance_upper': 7000.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.5,
#    'chi_eff_lower': -1.1,
#    'chi_eff_upper': 0.4,
#    'chi_eff_unit': '',
#    'total_mass_source': 130.0,
#    'total_mass_source_lower': -40.0,
#    'total_mass_source_upper': 110.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 51.0,
#    'chirp_mass_source_lower': -19.0,
#    'chirp_mass_source_upper': 29.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 120.0,
#    'chirp_mass_lower': -70.0,
#    'chirp_mass_upper': 40.0,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 1.2,
#    'redshift_lower': -0.8,
#    'redshift_upper': 0.9,
#    'redshift_unit': '',
#    'far': 1.5,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.64,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_upper': None,
#    'final_mass_source_unit': None},
#   'GW190707_083226-v1': {'commonName': 'GW190707_083226',
#    'version': 1,
#    'catalog.shortName': 'IAS-O3a',
#    'GPS': 1246523564.9,
#    'reference': '/IAS-O3a/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/IAS-O3a/GW190707_083226/v1',
#    'mass_1_source': 52.0,
#    'mass_1_source_lower': -14.0,
#    'mass_1_source_upper': 78.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 32.0,
#    'mass_2_source_lower': -19.0,
#    'mass_2_source_upper': 15.0,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 8.28,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 4000.0,
#    'luminosity_distance_lower': -2000.0,
#    'luminosity_distance_upper': 5000.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': -0.2,
#    'chi_eff_lower': -0.7,
#    'chi_eff_upper': 0.8,
#    'chi_eff_unit': '',
#    'total_mass_source': 85.0,
#    'total_mass_source_lower': -18.0,
#    'total_mass_source_upper': 73.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 35.0,
#    'chirp_mass_source_lower': -10.0,
#    'chirp_mass_source_upper': 16.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 60.0,
#    'chirp_mass_lower': -20.0,
#    'chirp_mass_upper': 40.0,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.6,
#    'redshift_lower': -0.3,
#    'redshift_upper': 0.6,
#    'redshift_unit': '',
#    'far': 0.043,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.94,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_upper': None,
#    'final_mass_source_unit': None},
#   'GW190706_222641-v1': {'commonName': 'GW190706_222641',
#    'version': 1,
#    'catalog.shortName': 'GWTC-2',
#    'GPS': 1246487219.3,
#    'reference': '/GWTC-2/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2/GW190706_222641/v1',
#    'mass_1_source': 67.0,
#    'mass_1_source_lower': -16.2,
#    'mass_1_source_upper': 14.6,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 38.2,
#    'mass_2_source_lower': -13.3,
#    'mass_2_source_upper': 14.6,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 12.653616083950073,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 4420.0,
#    'luminosity_distance_lower': -1930.0,
#    'luminosity_distance_upper': 2590.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.28,
#    'chi_eff_lower': -0.29,
#    'chi_eff_upper': 0.26,
#    'chi_eff_unit': '',
#    'total_mass_source': 104.1,
#    'total_mass_source_lower': -13.9,
#    'total_mass_source_upper': 20.2,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 42.7,
#    'chirp_mass_source_lower': -7.0,
#    'chirp_mass_source_upper': 10.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 75.1,
#    'chirp_mass_lower': -17.5,
#    'chirp_mass_upper': 11.0,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.71,
#    'redshift_lower': -0.27,
#    'redshift_upper': 0.32,
#    'redshift_unit': '',
#    'far': 1e-05,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 99.0,
#    'final_mass_source_lower': -13.5,
#    'final_mass_source_upper': 18.3,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190706_222641-v2': {'commonName': 'GW190706_222641',
#    'version': 2,
#    'catalog.shortName': 'GWTC-2.1-confident',
#    'GPS': 1246487219.3,
#    'reference': '/GWTC-2.1/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2.1-confident/GW190706_222641/v2',
#    'mass_1_source': 74.0,
#    'mass_1_source_lower': -16.9,
#    'mass_1_source_upper': 20.1,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 39.4,
#    'mass_2_source_lower': -15.4,
#    'mass_2_source_upper': 18.4,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 13.4,
#    'network_matched_filter_snr_lower': -0.4,
#    'network_matched_filter_snr_upper': 0.2,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 3630.0,
#    'luminosity_distance_lower': -2000.0,
#    'luminosity_distance_upper': 2600.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.28,
#    'chi_eff_lower': -0.31,
#    'chi_eff_upper': 0.25,
#    'chi_eff_unit': '',
#    'total_mass_source': 112.6,
#    'total_mass_source_lower': -16.8,
#    'total_mass_source_upper': 27.4,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 45.6,
#    'chirp_mass_source_lower': -9.1,
#    'chirp_mass_source_upper': 13.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.6,
#    'redshift_lower': -0.29,
#    'redshift_upper': 0.33,
#    'redshift_unit': '',
#    'far': 5e-05,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 107.3,
#    'final_mass_source_lower': -15.9,
#    'final_mass_source_upper': 25.2,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190706_222641-v3': {'commonName': 'GW190706_222641',
#    'version': 3,
#    'catalog.shortName': 'IAS-O3a',
#    'GPS': 1246487219.3,
#    'reference': '/IAS-O3a/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/IAS-O3a/GW190706_222641/v3',
#    'mass_1_source': 67.0,
#    'mass_1_source_lower': -17.0,
#    'mass_1_source_upper': 103.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 38.0,
#    'mass_2_source_lower': -20.0,
#    'mass_2_source_upper': 20.0,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 13.1,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 5000.0,
#    'luminosity_distance_lower': -3000.0,
#    'luminosity_distance_upper': 3000.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.4,
#    'chi_eff_lower': -1.0,
#    'chi_eff_upper': 0.3,
#    'chi_eff_unit': '',
#    'total_mass_source': 104.0,
#    'total_mass_source_lower': -15.0,
#    'total_mass_source_upper': 107.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 42.0,
#    'chirp_mass_source_lower': -10.0,
#    'chirp_mass_source_upper': 25.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 80.0,
#    'chirp_mass_lower': -30.0,
#    'chirp_mass_upper': 40.0,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.8,
#    'redshift_lower': -0.5,
#    'redshift_upper': 0.4,
#    'redshift_unit': '',
#    'far': 0.001,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_upper': None,
#    'final_mass_source_unit': None},
#   'GW190701_203306-v1': {'commonName': 'GW190701_203306',
#    'version': 1,
#    'catalog.shortName': 'GWTC-2',
#    'GPS': 1246048404.6,
#    'reference': '/GWTC-2/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2/GW190701_203306/v1',
#    'mass_1_source': 53.9,
#    'mass_1_source_lower': -8.0,
#    'mass_1_source_upper': 11.8,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 40.8,
#    'mass_2_source_lower': -12.0,
#    'mass_2_source_upper': 8.7,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 11.58996006414267,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 2060.0,
#    'luminosity_distance_lower': -730.0,
#    'luminosity_distance_upper': 760.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': -0.07,
#    'chi_eff_lower': -0.29,
#    'chi_eff_upper': 0.23,
#    'chi_eff_unit': '',
#    'total_mass_source': 94.3,
#    'total_mass_source_lower': -9.5,
#    'total_mass_source_upper': 12.1,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 40.3,
#    'chirp_mass_source_lower': -4.9,
#    'chirp_mass_source_upper': 5.4,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 55.5,
#    'chirp_mass_lower': -8.1,
#    'chirp_mass_upper': 7.3,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.37,
#    'redshift_lower': -0.12,
#    'redshift_upper': 0.11,
#    'redshift_unit': '',
#    'far': 0.010861368605368522,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.997879,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 90.2,
#    'final_mass_source_lower': -8.9,
#    'final_mass_source_upper': 11.3,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190701_203306-v2': {'commonName': 'GW190701_203306',
#    'version': 2,
#    'catalog.shortName': 'GWTC-2.1-confident',
#    'GPS': 1246048404.5,
#    'reference': '/GWTC-2.1/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2.1-confident/GW190701_203306/v2',
#    'mass_1_source': 54.1,
#    'mass_1_source_lower': -8.0,
#    'mass_1_source_upper': 12.6,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 40.5,
#    'mass_2_source_lower': -12.1,
#    'mass_2_source_upper': 8.7,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 11.2,
#    'network_matched_filter_snr_lower': -0.4,
#    'network_matched_filter_snr_upper': 0.2,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 2090.0,
#    'luminosity_distance_lower': -740.0,
#    'luminosity_distance_upper': 770.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': -0.08,
#    'chi_eff_lower': -0.31,
#    'chi_eff_upper': 0.23,
#    'chi_eff_unit': '',
#    'total_mass_source': 94.3,
#    'total_mass_source_lower': -9.5,
#    'total_mass_source_upper': 12.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 40.2,
#    'chirp_mass_source_lower': -5.0,
#    'chirp_mass_source_upper': 5.4,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.38,
#    'redshift_lower': -0.12,
#    'redshift_upper': 0.11,
#    'redshift_unit': '',
#    'far': 0.0057,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.99986,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 90.2,
#    'final_mass_source_lower': -8.9,
#    'final_mass_source_upper': 11.2,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190620_030421-v1': {'commonName': 'GW190620_030421',
#    'version': 1,
#    'catalog.shortName': 'GWTC-2',
#    'GPS': 1245035079.3,
#    'reference': '/GWTC-2/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2/GW190620_030421/v1',
#    'mass_1_source': 57.1,
#    'mass_1_source_lower': -12.7,
#    'mass_1_source_upper': 16.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 35.5,
#    'mass_2_source_lower': -12.3,
#    'mass_2_source_upper': 12.2,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 10.91846314686192,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 2810.0,
#    'luminosity_distance_lower': -1310.0,
#    'luminosity_distance_upper': 1680.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.33,
#    'chi_eff_lower': -0.25,
#    'chi_eff_upper': 0.22,
#    'chi_eff_unit': '',
#    'total_mass_source': 92.1,
#    'total_mass_source_lower': -13.1,
#    'total_mass_source_upper': 18.5,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 38.3,
#    'chirp_mass_source_lower': -6.5,
#    'chirp_mass_source_upper': 8.3,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 57.5,
#    'chirp_mass_lower': -11.2,
#    'chirp_mass_upper': 9.0,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.49,
#    'redshift_lower': -0.2,
#    'redshift_upper': 0.23,
#    'redshift_unit': '',
#    'far': 0.0029209383726319974,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.999133,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 87.2,
#    'final_mass_source_lower': -12.1,
#    'final_mass_source_upper': 16.8,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190620_030421-v2': {'commonName': 'GW190620_030421',
#    'version': 2,
#    'catalog.shortName': 'GWTC-2.1-confident',
#    'GPS': 1245035079.3,
#    'reference': '/GWTC-2.1/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2.1-confident/GW190620_030421/v2',
#    'mass_1_source': 58.0,
#    'mass_1_source_lower': -13.3,
#    'mass_1_source_upper': 19.2,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 35.0,
#    'mass_2_source_lower': -14.5,
#    'mass_2_source_upper': 13.1,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 12.1,
#    'network_matched_filter_snr_lower': -0.4,
#    'network_matched_filter_snr_upper': 0.3,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 2910.0,
#    'luminosity_distance_lower': -1320.0,
#    'luminosity_distance_upper': 1710.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.34,
#    'chi_eff_lower': -0.29,
#    'chi_eff_upper': 0.22,
#    'chi_eff_unit': '',
#    'total_mass_source': 92.7,
#    'total_mass_source_lower': -13.2,
#    'total_mass_source_upper': 18.5,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 38.1,
#    'chirp_mass_source_lower': -7.2,
#    'chirp_mass_source_upper': 8.5,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.5,
#    'redshift_lower': -0.2,
#    'redshift_upper': 0.23,
#    'redshift_unit': '',
#    'far': 0.011,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.98748,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 88.0,
#    'final_mass_source_lower': -12.4,
#    'final_mass_source_upper': 17.2,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190602_175927-v1': {'commonName': 'GW190602_175927',
#    'version': 1,
#    'catalog.shortName': 'GWTC-2',
#    'GPS': 1243533585.1,
#    'reference': '/GWTC-2/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2/GW190602_175927/v1',
#    'mass_1_source': 69.1,
#    'mass_1_source_lower': -13.0,
#    'mass_1_source_upper': 15.7,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 47.8,
#    'mass_2_source_lower': -17.4,
#    'mass_2_source_upper': 14.3,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 12.13087548611321,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 2690.0,
#    'luminosity_distance_lower': -1120.0,
#    'luminosity_distance_upper': 1790.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.07,
#    'chi_eff_lower': -0.24,
#    'chi_eff_upper': 0.25,
#    'chi_eff_unit': '',
#    'total_mass_source': 116.3,
#    'total_mass_source_lower': -15.6,
#    'total_mass_source_upper': 19.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 49.1,
#    'chirp_mass_source_lower': -8.5,
#    'chirp_mass_source_upper': 9.1,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 72.9,
#    'chirp_mass_lower': -13.7,
#    'chirp_mass_upper': 10.8,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.47,
#    'redshift_lower': -0.17,
#    'redshift_upper': 0.25,
#    'redshift_unit': '',
#    'far': 1.1478437256536947e-05,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.999994,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 110.9,
#    'final_mass_source_lower': -14.9,
#    'final_mass_source_upper': 17.7,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190602_175927-v2': {'commonName': 'GW190602_175927',
#    'version': 2,
#    'catalog.shortName': 'GWTC-2.1-confident',
#    'GPS': 1243533585.0,
#    'reference': '/GWTC-2.1/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2.1-confident/GW190602_175927/v2',
#    'mass_1_source': 71.8,
#    'mass_1_source_lower': -14.6,
#    'mass_1_source_upper': 18.1,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 44.8,
#    'mass_2_source_lower': -19.6,
#    'mass_2_source_upper': 15.5,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 13.2,
#    'network_matched_filter_snr_lower': -0.3,
#    'network_matched_filter_snr_upper': 0.2,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 2840.0,
#    'luminosity_distance_lower': -1280.0,
#    'luminosity_distance_upper': 1930.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.12,
#    'chi_eff_lower': -0.28,
#    'chi_eff_upper': 0.25,
#    'chi_eff_unit': '',
#    'total_mass_source': 115.6,
#    'total_mass_source_lower': -14.8,
#    'total_mass_source_upper': 19.2,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 48.0,
#    'chirp_mass_source_lower': -9.7,
#    'chirp_mass_source_upper': 9.5,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.49,
#    'redshift_lower': -0.2,
#    'redshift_upper': 0.26,
#    'redshift_unit': '',
#    'far': 1e-05,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 110.5,
#    'final_mass_source_lower': -13.9,
#    'final_mass_source_upper': 17.9,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190602_175927-v3': {'commonName': 'GW190602_175927',
#    'version': 3,
#    'catalog.shortName': 'IAS-O3a',
#    'GPS': 1243533585.1,
#    'reference': '/IAS-O3a/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/IAS-O3a/GW190602_175927/v3',
#    'mass_1_source': 73.0,
#    'mass_1_source_lower': -17.0,
#    'mass_1_source_upper': 98.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 44.0,
#    'mass_2_source_lower': -25.0,
#    'mass_2_source_upper': 19.0,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 12.4,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 3000.0,
#    'luminosity_distance_lower': -1900.0,
#    'luminosity_distance_upper': 2600.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.2,
#    'chi_eff_lower': -0.9,
#    'chi_eff_upper': 0.4,
#    'chi_eff_unit': '',
#    'total_mass_source': 120.0,
#    'total_mass_source_lower': -20.0,
#    'total_mass_source_upper': 90.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 49.0,
#    'chirp_mass_source_lower': -14.0,
#    'chirp_mass_source_upper': 21.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 80.0,
#    'chirp_mass_lower': -40.0,
#    'chirp_mass_upper': 30.0,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.5,
#    'redshift_lower': -0.3,
#    'redshift_upper': 0.4,
#    'redshift_unit': '',
#    'far': 0.001,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_upper': None,
#    'final_mass_source_unit': None},
#   'GW190521-v2': {'commonName': 'GW190521',
#    'version': 2,
#    'catalog.shortName': 'O3_Discovery_Papers',
#    'GPS': 1242442967.4,
#    'reference': '/o3_eventdata_docs/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/O3_Discovery_Papers/GW190521/v2',
#    'mass_1_source': 85.0,
#    'mass_1_source_lower': -14.0,
#    'mass_1_source_upper': 21.0,
#    'mass_1_source_unit': '',
#    'mass_2_source': 66.0,
#    'mass_2_source_lower': -18.0,
#    'mass_2_source_upper': 17.0,
#    'mass_2_source_unit': '',
#    'network_matched_filter_snr': 14.6,
#    'network_matched_filter_snr_lower': -0.4,
#    'network_matched_filter_snr_upper': 0.4,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 5300.0,
#    'luminosity_distance_lower': -2600.0,
#    'luminosity_distance_upper': 2400.0,
#    'luminosity_distance_unit': '',
#    'chi_eff': 0.08,
#    'chi_eff_lower': -0.36,
#    'chi_eff_upper': 0.27,
#    'chi_eff_unit': '',
#    'total_mass_source': 150.0,
#    'total_mass_source_lower': -17.0,
#    'total_mass_source_upper': 29.0,
#    'total_mass_source_unit': '',
#    'chirp_mass_source': 64.0,
#    'chirp_mass_source_lower': -8.0,
#    'chirp_mass_source_upper': 13.0,
#    'chirp_mass_source_unit': '',
#    'chirp_mass': 117.0,
#    'chirp_mass_lower': -14.0,
#    'chirp_mass_upper': 12.0,
#    'chirp_mass_unit': '',
#    'redshift': 0.82,
#    'redshift_lower': -0.34,
#    'redshift_upper': 0.28,
#    'redshift_unit': '',
#    'far': None,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_upper': None,
#    'final_mass_source_unit': None},
#   'GW190521-v3': {'commonName': 'GW190521',
#    'version': 3,
#    'catalog.shortName': 'GWTC-2',
#    'GPS': 1242442967.4,
#    'reference': '/GWTC-2/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2/GW190521/v3',
#    'mass_1_source': 95.3,
#    'mass_1_source_lower': -18.9,
#    'mass_1_source_upper': 28.7,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 69.0,
#    'mass_2_source_lower': -23.1,
#    'mass_2_source_upper': 22.7,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 14.376046048896756,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 3920.0,
#    'luminosity_distance_lower': -1950.0,
#    'luminosity_distance_upper': 2190.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.03,
#    'chi_eff_lower': -0.39,
#    'chi_eff_upper': 0.32,
#    'chi_eff_unit': '',
#    'total_mass_source': 163.9,
#    'total_mass_source_lower': -23.5,
#    'total_mass_source_upper': 39.2,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 69.2,
#    'chirp_mass_source_lower': -10.6,
#    'chirp_mass_source_upper': 17.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 114.8,
#    'chirp_mass_lower': -17.6,
#    'chirp_mass_upper': 15.2,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.64,
#    'redshift_lower': -0.28,
#    'redshift_upper': 0.28,
#    'redshift_unit': '',
#    'far': 0.0002039635028,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.999624,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 156.3,
#    'final_mass_source_lower': -22.4,
#    'final_mass_source_upper': 36.8,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190521_030229-v4': {'commonName': 'GW190521',
#    'version': 4,
#    'catalog.shortName': 'GWTC-2.1-confident',
#    'GPS': 1242442967.4,
#    'reference': '/GWTC-2.1/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2.1-confident/GW190521/v4',
#    'mass_1_source': 98.4,
#    'mass_1_source_lower': -21.7,
#    'mass_1_source_upper': 33.6,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 57.2,
#    'mass_2_source_lower': -30.1,
#    'mass_2_source_upper': 27.1,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 14.3,
#    'network_matched_filter_snr_lower': -0.4,
#    'network_matched_filter_snr_upper': 0.5,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 3310.0,
#    'luminosity_distance_lower': -1800.0,
#    'luminosity_distance_upper': 2790.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': -0.14,
#    'chi_eff_lower': -0.45,
#    'chi_eff_upper': 0.5,
#    'chi_eff_unit': '',
#    'total_mass_source': 153.1,
#    'total_mass_source_lower': -16.2,
#    'total_mass_source_upper': 42.2,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 63.3,
#    'chirp_mass_source_lower': -14.6,
#    'chirp_mass_source_upper': 19.6,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.56,
#    'redshift_lower': -0.27,
#    'redshift_upper': 0.36,
#    'redshift_unit': '',
#    'far': 0.0013,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.99989,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 147.4,
#    'final_mass_source_lower': -16.0,
#    'final_mass_source_upper': 40.0,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190519_153544-v1': {'commonName': 'GW190519_153544',
#    'version': 1,
#    'catalog.shortName': 'GWTC-2',
#    'GPS': 1242315362.4,
#    'reference': '/GWTC-2/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2/GW190519_153544/v1',
#    'mass_1_source': 66.0,
#    'mass_1_source_lower': -12.0,
#    'mass_1_source_upper': 10.7,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 40.5,
#    'mass_2_source_lower': -11.1,
#    'mass_2_source_upper': 11.0,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 13.952630576346527,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 2530.0,
#    'luminosity_distance_lower': -920.0,
#    'luminosity_distance_upper': 1830.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.31,
#    'chi_eff_lower': -0.22,
#    'chi_eff_upper': 0.2,
#    'chi_eff_unit': '',
#    'total_mass_source': 106.6,
#    'total_mass_source_lower': -14.8,
#    'total_mass_source_upper': 13.5,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 44.5,
#    'chirp_mass_source_lower': -7.1,
#    'chirp_mass_source_upper': 6.4,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 65.1,
#    'chirp_mass_lower': -10.3,
#    'chirp_mass_upper': 7.7,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.44,
#    'redshift_lower': -0.14,
#    'redshift_upper': 0.25,
#    'redshift_unit': '',
#    'far': 1e-05,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 101.0,
#    'final_mass_source_lower': -13.8,
#    'final_mass_source_upper': 12.4,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190519_153544-v2': {'commonName': 'GW190519_153544',
#    'version': 2,
#    'catalog.shortName': 'GWTC-2.1-confident',
#    'GPS': 1242315362.3,
#    'reference': '/GWTC-2.1/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2.1-confident/GW190519_153544/v2',
#    'mass_1_source': 65.1,
#    'mass_1_source_lower': -11.0,
#    'mass_1_source_upper': 10.8,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 40.8,
#    'mass_2_source_lower': -12.7,
#    'mass_2_source_upper': 11.5,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 15.9,
#    'network_matched_filter_snr_lower': -0.3,
#    'network_matched_filter_snr_upper': 0.2,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 2600.0,
#    'luminosity_distance_lower': -960.0,
#    'luminosity_distance_upper': 1720.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.33,
#    'chi_eff_lower': -0.24,
#    'chi_eff_upper': 0.2,
#    'chi_eff_unit': '',
#    'total_mass_source': 105.6,
#    'total_mass_source_lower': -13.9,
#    'total_mass_source_upper': 14.4,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 44.3,
#    'chirp_mass_source_lower': -7.5,
#    'chirp_mass_source_upper': 6.8,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.45,
#    'redshift_lower': -0.15,
#    'redshift_upper': 0.24,
#    'redshift_unit': '',
#    'far': 1e-05,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 100.0,
#    'final_mass_source_lower': -12.9,
#    'final_mass_source_upper': 13.0,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190519_153544-v3': {'commonName': 'GW190519_153544',
#    'version': 3,
#    'catalog.shortName': 'IAS-O3a',
#    'GPS': 1242315362.4,
#    'reference': '/IAS-O3a/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/IAS-O3a/GW190519_153544/v3',
#    'mass_1_source': 62.0,
#    'mass_1_source_lower': -14.0,
#    'mass_1_source_upper': 93.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 41.0,
#    'mass_2_source_lower': -23.0,
#    'mass_2_source_upper': 14.0,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 14.5,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 3000.0,
#    'luminosity_distance_lower': -1600.0,
#    'luminosity_distance_upper': 3000.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.4,
#    'chi_eff_lower': -1.0,
#    'chi_eff_upper': 0.3,
#    'chi_eff_unit': '',
#    'total_mass_source': 103.0,
#    'total_mass_source_lower': -19.0,
#    'total_mass_source_upper': 92.0,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 43.0,
#    'chirp_mass_source_lower': -13.0,
#    'chirp_mass_source_upper': 19.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': 70.0,
#    'chirp_mass_lower': -30.0,
#    'chirp_mass_upper': 40.0,
#    'chirp_mass_unit': 'M_sun',
#    'redshift': 0.5,
#    'redshift_lower': -0.2,
#    'redshift_upper': 0.4,
#    'redshift_unit': '',
#    'far': 0.001,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 1.0,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_upper': None,
#    'final_mass_source_unit': None},
#   'GW190426_190642-v1': {'commonName': 'GW190426_190642',
#    'version': 1,
#    'catalog.shortName': 'GWTC-2.1-confident',
#    'GPS': 1240340820.6,
#    'reference': '/GWTC-2.1/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2.1-confident/GW190426_190642/v1',
#    'mass_1_source': 105.5,
#    'mass_1_source_lower': -24.1,
#    'mass_1_source_upper': 45.3,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 76.0,
#    'mass_2_source_lower': -36.5,
#    'mass_2_source_upper': 26.2,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 8.7,
#    'network_matched_filter_snr_lower': -0.6,
#    'network_matched_filter_snr_upper': 0.4,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 4580.0,
#    'luminosity_distance_lower': -2280.0,
#    'luminosity_distance_upper': 3400.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.23,
#    'chi_eff_lower': -0.41,
#    'chi_eff_upper': 0.42,
#    'chi_eff_unit': '',
#    'total_mass_source': 182.3,
#    'total_mass_source_lower': -35.7,
#    'total_mass_source_upper': 40.2,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 76.0,
#    'chirp_mass_source_lower': -17.4,
#    'chirp_mass_source_upper': 19.1,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.73,
#    'redshift_lower': -0.32,
#    'redshift_upper': 0.41,
#    'redshift_unit': '',
#    'far': 4.1,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.75053,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 172.9,
#    'final_mass_source_lower': -33.6,
#    'final_mass_source_upper': 37.7,
#    'final_mass_source_unit': 'M_sun'},
#   'GW190413_134308-v2': {'commonName': 'GW190413_134308',
#    'version': 2,
#    'catalog.shortName': 'GWTC-2.1-confident',
#    'GPS': 1239198206.7,
#    'reference': '/GWTC-2.1/',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-2.1-confident/GW190413_134308/v2',
#    'mass_1_source': 51.3,
#    'mass_1_source_lower': -12.6,
#    'mass_1_source_upper': 16.6,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 30.4,
#    'mass_2_source_lower': -12.7,
#    'mass_2_source_upper': 11.7,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 10.6,
#    'network_matched_filter_snr_lower': -0.5,
#    'network_matched_filter_snr_upper': 0.4,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 3800.0,
#    'luminosity_distance_lower': -1830.0,
#    'luminosity_distance_upper': 2480.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': -0.01,
#    'chi_eff_lower': -0.38,
#    'chi_eff_upper': 0.28,
#    'chi_eff_unit': '',
#    'total_mass_source': 81.3,
#    'total_mass_source_lower': -11.8,
#    'total_mass_source_upper': 16.8,
#    'total_mass_source_unit': 'M_sun',
#    'chirp_mass_source': 33.3,
#    'chirp_mass_source_lower': -6.3,
#    'chirp_mass_source_upper': 7.8,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.62,
#    'redshift_lower': -0.26,
#    'redshift_upper': 0.32,
#    'redshift_unit': '',
#    'far': 0.18,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': '1/yr',
#    'p_astro': 0.99058,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 78.0,
#    'final_mass_source_lower': -11.5,
#    'final_mass_source_upper': 16.1,
#    'final_mass_source_unit': 'M_sun'},
#   'GW170729-v1': {'commonName': 'GW170729',
#    'version': 1,
#    'catalog.shortName': 'GWTC-1-confident',
#    'GPS': 1185389807.3,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'jsonurl': 'https://gwosc.org/eventapi/json/GWTC-1-confident/GW170729/v1',
#    'mass_1_source': 50.2,
#    'mass_1_source_lower': -10.2,
#    'mass_1_source_upper': 16.2,
#    'mass_1_source_unit': 'M_sun',
#    'mass_2_source': 34.0,
#    'mass_2_source_lower': -10.1,
#    'mass_2_source_upper': 9.1,
#    'mass_2_source_unit': 'M_sun',
#    'network_matched_filter_snr': 10.8,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_upper': None,
#    'network_matched_filter_snr_unit': '',
#    'luminosity_distance': 2840.0,
#    'luminosity_distance_lower': -1360.0,
#    'luminosity_distance_upper': 1400.0,
#    'luminosity_distance_unit': 'Mpc',
#    'chi_eff': 0.37,
#    'chi_eff_lower': -0.25,
#    'chi_eff_upper': 0.21,
#    'chi_eff_unit': '',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_upper': None,
#    'total_mass_source_unit': None,
#    'chirp_mass_source': 35.4,
#    'chirp_mass_source_lower': -4.8,
#    'chirp_mass_source_upper': 6.5,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_upper': None,
#    'chirp_mass_unit': None,
#    'redshift': 0.49,
#    'redshift_lower': -0.21,
#    'redshift_upper': 0.19,
#    'redshift_unit': '',
#    'far': 0.02,
#    'far_lower': None,
#    'far_upper': None,
#    'far_unit': 'yr^-1',
#    'p_astro': 0.98,
#    'p_astro_lower': None,
#    'p_astro_upper': None,
#    'p_astro_unit': '',
#    'final_mass_source': 79.5,
#    'final_mass_source_lower': -10.2,
#    'final_mass_source_upper': 14.7,
#    'final_mass_source_unit': 'M_sun'}}}
